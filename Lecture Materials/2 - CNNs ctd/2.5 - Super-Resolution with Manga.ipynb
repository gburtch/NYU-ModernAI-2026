# %% [markdown]
# ##**Image-Sharpening ConvNet**

# %% [markdown]
# We are going to work with high-res images of a bunch of manga comicbook covers. Word of warning: high-res images means tons of pixels, which means tons of data in memory and big tensor operations.

# %% [markdown]
# # Import Dataset

# %% [markdown]
# Mount Google Drive.

# %%
import pandas as pd
from google.colab import files
import io

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load the image dataset and manipulate it.

# %%
import numpy as np
import glob
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

image_list = []
for file in glob.glob("/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/2 - CNNs ctd/manga_low/*"):
    im=Image.open(file)

    # I am stripping off the last row. Why?
    img_array = np.array(im)[:-1,:,:]

    # I am adding two cols of white pixels too. Why?
    white = np.ones(shape=(584,2,3))*255
    img_array = np.hstack([img_array,white])
    img_array = np.divide(img_array,255)
    image_list.append(img_array)

dpi = 80

height, width, depth = image_list[0].shape
figsize = width / float(dpi), height / float(dpi)

print(f'The shape of each image is {image_list[0].shape}.')

plt.figure(figsize=figsize)
plt.imshow(image_list[0])
plt.show()
# Out:
# The shape of each image is (584, 416, 3).

# %% [markdown]
# #*Optional: Dataset Augmentation.*

# %% [markdown]
# With image data, it's pretty straight forward for us to synthesize new training examples by copying and then randomly manipulating the images we've already got!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

datagen = ImageDataGenerator(
    rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# First, 'train' the image data generator on our sample.
datagen.fit(image_list)

# Now we create the iterator... we can keep pulling new randomly transformed pictures out of this forever.
image_batches = datagen.flow(np.stack(image_list,axis=0), batch_size=30)

n = 5
plt.figure(figsize= (20,10))

q = 0
for i,batch in enumerate(image_batches):
    for j, image in enumerate(batch):
        if j == 1:
            # Only plot the first 6 photos.
            if i <= 5:
                ax = plt.subplot(1, 6, i+1)
                plt.imshow(tf.keras.utils.array_to_img(image))
                ax.get_xaxis().set_visible(False)
                ax.get_yaxis().set_visible(False)

        # The iterator outputs image data with pixel values between 0-1; we are using values between 0-255 elsewhere.
        # We need to make the pixel values align.
        image_list.append(np.multiply(image,255))

    # Telling the script to stop asking for new images after several batches.
    if q > 5:
      break

    q += 1

plt.show()

print(f'We now have a total of {len(image_list)} images.')
# Out:
# We now have a total of 304 images.

# %% [markdown]
# Lastly, let's make our X's now; the pixellated versions of the high resolution images.

# %%
import tensorflow as tf
import numpy as np

pixelated_list = []

# This part determines how difficult the problem is.
# If we downsample too much, there's not enough signal left in the data to recover the original.
# Try this with downsampling to 100x100 or even lower. The model won't be able to solve the problem.
for image in image_list:
  image = Image.fromarray(np.multiply(image,255).astype('uint8'))

  # Next, make the pixelated version of the original image.
  image_tiny = image.resize((100,100))    # resize it to a tiny size
  pixelated = image_tiny.resize(image.size,Image.NEAREST)   # scale it back up

  # Store the pixelated photo.
  pixelated = tf.keras.utils.img_to_array(pixelated)
  pixelated_list.append(pixelated)

# We will put these into NumPy arrays for use in our NN later.
pixelated_array = np.stack(pixelated_list, axis=0)
image_array = np.stack(image_list, axis=0)

# Let's plot the first 5 pairs of training images and their labels (in RGB).
n = 5
plt.figure(figsize= (20,10))

for i in range(n):
  ax = plt.subplot(2, n, i+1)
  plt.imshow(tf.keras.utils.array_to_img(pixelated_list[i]))
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  ax = plt.subplot(2, n, i+1+n)
  plt.imshow(tf.keras.utils.array_to_img(image_list[i]))
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# # Create Our Neural Network

# %% [markdown]
# Now, we just need to create a model that takes the pixelated image as input, and tries to predict the original.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import math
#from keras import backend as K

# PSNR is 'positive signal to noise ratio', a loss metric that is specific to assessing image quality.
# This is a custom loss function we are defining for use here.
# Note, higher PSNR is desirable, so we multiple the number by -1 because optimizers minimize loss by default.
# Multiplying by -1 tricks the optimizer into maximizing instead of minimizing.

def psnrLoss(y_true, y_pred, max_pixel=255.0):
    psnr = tf.image.psnr(y_true,y_pred,max_val=max_pixel)
    return -1*psnr

# Batch size is unstated for now, but a given observation has height and width of images, and 3 color channels.
inputs = keras.Input(shape=(height, width, 3))

# Encoder portion
x = layers.Conv2D(16, (3,3), activation="relu", padding="same")(inputs)
x = layers.Conv2D(16, (3,3), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2,2), padding="same")(x)

x = layers.Conv2D(32, (3,3), activation="relu", padding="same")(x)
x = layers.Conv2D(32, (3,3), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2,2), padding="same")(x)

x = layers.Conv2D(64, (3,3), padding="same", activation="relu")(x)
x = layers.Conv2D(64, (3,3), padding="same", activation="relu")(x)
x = layers.MaxPooling2D((2,2), padding="same")(x)

x = layers.Conv2D(128, (3,3), activation="relu", padding="same")(x)
encoding = layers.Conv2D(128, (3,3), activation="relu", padding="same")(x)

# Decoder portion
x = layers.Conv2DTranspose(64, (3,3), strides=2,activation="relu", padding="same")(encoding)
x = layers.Conv2DTranspose(32, (3,3), strides=2,activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(16, (3,3), strides=2, activation="relu", padding="same")(x)

outputs = layers.Conv2D(3, (3,3), activation="sigmoid", padding="same")(x)

model = keras.Model(inputs, outputs)

# Compile the model with our custom loss function.
model.compile(optimizer="adam", loss=psnrLoss, metrics=['mse'])

keras.utils.plot_model(model, show_shapes=True, dpi=60)

# %% [markdown]
# We can get a summary of the trainable parameters in our network...

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 584, 416, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 584, 416, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 584, 416, 16)   │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 292, 208, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 292, 208, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 292, 208, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 146, 104, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 146, 104, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 146, 104, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 73, 52, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 73, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 73, 52, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_9              │ (None, 146, 104, 64)   │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_10             │ (None, 292, 208, 32)   │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_11             │ (None, 584, 416, 16)   │         4,624 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 584, 416, 3)    │           435 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 390,835 (1.49 MB)
#  Trainable params: 390,835 (1.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Okay, let's try fitting this model...

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/2 - CNNs ctd/superResolution.keras",
                                    save_best_only=True)
]

history = model.fit(pixelated_array,image_array,batch_size=16, epochs=100, validation_split=0.2,callbacks=callbacks)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: -56.9311 - mse: 0.1393 - val_loss: -58.4364 - val_mse: 0.0972
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: -59.0092 - mse: 0.0860 - val_loss: -60.6864 - val_mse: 0.0602
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: -60.2441 - mse: 0.0665 - val_loss: -61.4407 - val_mse: 0.0509
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: -61.2596 - mse: 0.0534 - val_loss: -61.8836 - val_mse: 0.0467
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: -61.8662 - mse: 0.0462 - val_loss: -62.6363 - val_mse: 0.0368
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: -62.8851 - mse: 0.0354 - val_loss: -63.8069 - val_mse: 0.0289
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: -63.4398 - mse: 0.0314 - val_loss: -63.3051 - val_mse: 0.0330
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: -63.5331 - mse: 0.0306 - val_loss: -64.6056 - val_mse: 0.0242
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: -64.1267 - mse: 0.0268 - val_loss: -64.4918 - val_mse: 0.0246
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: -64.3310 - mse: 0.0256 - val_loss: -65.1174 - val_mse: 0.0216
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: -64.8012 - mse: 0.0228 - val_loss: -65.5497 - val_mse: 0.0198
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: -64.9343 - mse: 0.0224 - val_loss: -65.3257 - val_mse: 0.0209
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: -65.1387 - mse: 0.0216 - val_loss: -65.8995 - val_mse: 0.0183
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: -65.3410 - mse: 0.0207 - val_loss: -66.1142 - val_mse: 0.0172
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: -65.4244 - mse: 0.0201 - val_loss: -66.1515 - val_mse: 0.0170
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: -65.6758 - mse: 0.0191 - val_loss: -65.3926 - val_mse: 0.0196
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: -65.6984 - mse: 0.0188 - val_loss: -65.9315 - val_mse: 0.0179
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: -65.6340 - mse: 0.0190 - val_loss: -66.6388 - val_mse: 0.0151
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: -65.7275 - mse: 0.0187 - val_loss: -65.9203 - val_mse: 0.0177
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: -65.7806 - mse: 0.0186 - val_loss: -67.1100 - val_mse: 0.0135
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -66.3041 - mse: 0.0165 - val_loss: -66.4525 - val_mse: 0.0157
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: -65.6315 - mse: 0.0193 - val_loss: -66.9486 - val_mse: 0.0139
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -66.5067 - mse: 0.0158 - val_loss: -67.1102 - val_mse: 0.0135
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -66.4545 - mse: 0.0159 - val_loss: -66.5332 - val_mse: 0.0155
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -66.3044 - mse: 0.0165 - val_loss: -67.5215 - val_mse: 0.0124
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -66.6662 - mse: 0.0153 - val_loss: -66.9651 - val_mse: 0.0138
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -66.5771 - mse: 0.0155 - val_loss: -67.1272 - val_mse: 0.0133
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -66.1900 - mse: 0.0171 - val_loss: -66.2215 - val_mse: 0.0162
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -66.2651 - mse: 0.0166 - val_loss: -67.3297 - val_mse: 0.0128
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: -66.7724 - mse: 0.0149 - val_loss: -67.9300 - val_mse: 0.0112
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: -67.1550 - mse: 0.0139 - val_loss: -68.1708 - val_mse: 0.0107
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.4356 - mse: 0.0132 - val_loss: -68.0683 - val_mse: 0.0109
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -66.7651 - mse: 0.0151 - val_loss: -66.8386 - val_mse: 0.0140
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: -66.5671 - mse: 0.0156 - val_loss: -67.7748 - val_mse: 0.0116
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -66.2769 - mse: 0.0169 - val_loss: -67.6551 - val_mse: 0.0119
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.0045 - mse: 0.0143 - val_loss: -67.4407 - val_mse: 0.0124
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -66.8619 - mse: 0.0147 - val_loss: -67.6655 - val_mse: 0.0119
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: -67.1410 - mse: 0.0139 - val_loss: -67.4035 - val_mse: 0.0125
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.0823 - mse: 0.0140 - val_loss: -68.0336 - val_mse: 0.0109
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: -67.5516 - mse: 0.0126 - val_loss: -68.5713 - val_mse: 0.0098
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.5721 - mse: 0.0126 - val_loss: -67.9492 - val_mse: 0.0112
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.1230 - mse: 0.0139 - val_loss: -67.3284 - val_mse: 0.0128
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -65.9715 - mse: 0.0179 - val_loss: -67.0384 - val_mse: 0.0138
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -66.0347 - mse: 0.0174 - val_loss: -66.6773 - val_mse: 0.0147
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -66.4243 - mse: 0.0160 - val_loss: -66.8448 - val_mse: 0.0140
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -66.7570 - mse: 0.0150 - val_loss: -67.7231 - val_mse: 0.0117
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.2004 - mse: 0.0137 - val_loss: -68.0476 - val_mse: 0.0110
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.5310 - mse: 0.0125 - val_loss: -68.2732 - val_mse: 0.0104
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -67.6769 - mse: 0.0124 - val_loss: -68.7631 - val_mse: 0.0095
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.7198 - mse: 0.0124 - val_loss: -68.7398 - val_mse: 0.0094
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -67.8602 - mse: 0.0119 - val_loss: -67.1029 - val_mse: 0.0134
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -67.7400 - mse: 0.0122 - val_loss: -68.9638 - val_mse: 0.0090
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -68.2765 - mse: 0.0109 - val_loss: -68.8557 - val_mse: 0.0093
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.2402 - mse: 0.0141 - val_loss: -67.8937 - val_mse: 0.0113
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.2562 - mse: 0.0134 - val_loss: -67.7144 - val_mse: 0.0117
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.2223 - mse: 0.0135 - val_loss: -67.9412 - val_mse: 0.0112
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.6493 - mse: 0.0124 - val_loss: -68.8551 - val_mse: 0.0092
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.9761 - mse: 0.0115 - val_loss: -68.6875 - val_mse: 0.0095
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -67.9453 - mse: 0.0117 - val_loss: -67.9363 - val_mse: 0.0111
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.3070 - mse: 0.0132 - val_loss: -68.8020 - val_mse: 0.0094
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -67.8444 - mse: 0.0120 - val_loss: -69.0468 - val_mse: 0.0089
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.1228 - mse: 0.0113 - val_loss: -68.9983 - val_mse: 0.0089
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -67.9184 - mse: 0.0117 - val_loss: -69.1467 - val_mse: 0.0087
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -68.2493 - mse: 0.0110 - val_loss: -69.2801 - val_mse: 0.0085
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.4012 - mse: 0.0106 - val_loss: -69.1638 - val_mse: 0.0086
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.0978 - mse: 0.0113 - val_loss: -69.1166 - val_mse: 0.0087
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.3437 - mse: 0.0109 - val_loss: -67.5473 - val_mse: 0.0121
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.1958 - mse: 0.0137 - val_loss: -68.2809 - val_mse: 0.0103
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.8053 - mse: 0.0118 - val_loss: -69.1228 - val_mse: 0.0087
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -68.1951 - mse: 0.0113 - val_loss: -69.2554 - val_mse: 0.0085
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: -68.1867 - mse: 0.0112 - val_loss: -69.4039 - val_mse: 0.0082
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -68.1398 - mse: 0.0113 - val_loss: -68.6637 - val_mse: 0.0095
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.8198 - mse: 0.0118 - val_loss: -68.5396 - val_mse: 0.0098
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.9861 - mse: 0.0115 - val_loss: -68.9060 - val_mse: 0.0091
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.8840 - mse: 0.0119 - val_loss: -68.1446 - val_mse: 0.0107
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -67.9242 - mse: 0.0117 - val_loss: -68.9105 - val_mse: 0.0090
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -68.0430 - mse: 0.0114 - val_loss: -69.2881 - val_mse: 0.0084
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.2995 - mse: 0.0108 - val_loss: -69.2987 - val_mse: 0.0084
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: -68.4354 - mse: 0.0105 - val_loss: -69.4137 - val_mse: 0.0082
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.4249 - mse: 0.0105 - val_loss: -68.5845 - val_mse: 0.0098
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.9812 - mse: 0.0118 - val_loss: -67.5191 - val_mse: 0.0120
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -67.2829 - mse: 0.0133 - val_loss: -68.4270 - val_mse: 0.0100
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.0190 - mse: 0.0114 - val_loss: -69.2038 - val_mse: 0.0085
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.2037 - mse: 0.0113 - val_loss: -69.3592 - val_mse: 0.0083
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: -68.5815 - mse: 0.0101 - val_loss: -69.3876 - val_mse: 0.0082
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: -68.6116 - mse: 0.0102 - val_loss: -69.5834 - val_mse: 0.0079
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.5440 - mse: 0.0103 - val_loss: -69.4644 - val_mse: 0.0081
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: -68.5757 - mse: 0.0102 - val_loss: -69.6142 - val_mse: 0.0079
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.7025 - mse: 0.0098 - val_loss: -69.4839 - val_mse: 0.0080
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.2164 - mse: 0.0111 - val_loss: -68.6846 - val_mse: 0.0094
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.3395 - mse: 0.0108 - val_loss: -68.8586 - val_mse: 0.0092
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.3555 - mse: 0.0108 - val_loss: -68.4525 - val_mse: 0.0099
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.3492 - mse: 0.0106 - val_loss: -69.4114 - val_mse: 0.0082
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -68.4813 - mse: 0.0104 - val_loss: -69.2383 - val_mse: 0.0085
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.4961 - mse: 0.0104 - val_loss: -69.5228 - val_mse: 0.0080
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: -68.6652 - mse: 0.0103 - val_loss: -69.7204 - val_mse: 0.0077
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.6627 - mse: 0.0102 - val_loss: -69.2430 - val_mse: 0.0085
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -68.1231 - mse: 0.0112 - val_loss: -69.3082 - val_mse: 0.0083
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: -68.3412 - mse: 0.0106 - val_loss: -69.4663 - val_mse: 0.0080
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: -68.5351 - mse: 0.0102 - val_loss: -69.5545 - val_mse: 0.0079

# %% [markdown]
# And, let's plot the loss over epochs...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_loss'][1:],c="b")
plt.plot(history.history['loss'][1:],c="r")
plt.legend(['Validation','Training'])
plt.show()

# %% [markdown]
# Let's spit out some of the predictions from this model to see how well it works...

# %%
custom_stuff = {'psnrLoss': psnrLoss}

model = keras.models.load_model("/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/2 - CNNs ctd/superResolution.keras",
                                custom_objects=custom_stuff)

sharpened_array = model.predict(pixelated_array[:15])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %% [markdown]
# Our sharpener works, though it has some trouble with white pixels (it fills in some black pixels). It may need more white examples to figure those out well.

# %%
n = 5
plt.figure(figsize= (20,10))

for i in range(n):
  ax = plt.subplot(2, n, i+1)
  plt.imshow((pixelated_array[i]).astype('uint8'))
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  ax = plt.subplot(2, n, i+1+n)
  plt.imshow((sharpened_array[i]))
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

plt.show()
