# %% [markdown]
# # Import Our Data

# %% [markdown]
# Load the data to your Google Drive. Then you can mount your drive and access the folder wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/dogs-vs-cats"

train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %% [markdown]
# We can look at the shape of a single batch coming from the tf.Dataset object now...

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_accuracy")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.4934 - loss: 0.8478 - val_accuracy: 0.5000 - val_loss: 0.8467
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.5463 - loss: 0.6979 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5254 - loss: 0.6943 - val_accuracy: 0.5050 - val_loss: 0.6919
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5161 - loss: 0.6906 - val_accuracy: 0.5225 - val_loss: 0.6903
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.5316 - loss: 0.6983 - val_accuracy: 0.5200 - val_loss: 0.6898
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6053 - loss: 0.6923 - val_accuracy: 0.5525 - val_loss: 0.6832
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.6202 - loss: 0.6786 - val_accuracy: 0.5625 - val_loss: 0.6752
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.5969 - loss: 0.6686 - val_accuracy: 0.5475 - val_loss: 0.7319
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6115 - loss: 0.6591 - val_accuracy: 0.6400 - val_loss: 0.6458
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.6660 - loss: 0.6088 - val_accuracy: 0.6200 - val_loss: 0.6424
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.6708 - loss: 0.5876 - val_accuracy: 0.6125 - val_loss: 0.7018
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.6918 - loss: 0.5729 - val_accuracy: 0.5750 - val_loss: 0.6883
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7361 - loss: 0.5531 - val_accuracy: 0.6525 - val_loss: 0.6504
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.7341 - loss: 0.5348 - val_accuracy: 0.6300 - val_loss: 0.6683
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7718 - loss: 0.4805 - val_accuracy: 0.6425 - val_loss: 0.6966
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7856 - loss: 0.4495 - val_accuracy: 0.6150 - val_loss: 0.7626
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8234 - loss: 0.4027 - val_accuracy: 0.6425 - val_loss: 0.8310
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8544 - loss: 0.3183 - val_accuracy: 0.5900 - val_loss: 0.9944
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8607 - loss: 0.2911 - val_accuracy: 0.6675 - val_loss: 0.9965
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8906 - loss: 0.2550 - val_accuracy: 0.6475 - val_loss: 1.1971

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we reach > 65% accuracy pretty quickly without much effort, but it plateaus there.

# %%
test_model = keras.models.load_model("/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6617 - loss: 0.9469
# Test accuracy: 0.646616518497467

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# To stave off the overfitting, we will first start by augmenting our dataset. This is a simple way to do it in a Sequential model, by adding a data augmentation layer. This step in our model will randomly mess with the data at each pass, flipping, rotating and zooming each image.

# %%
data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

# %% [markdown]
# You'll see that adding the aaumentation layer gets us another 5% bump in the validation accuracy of our model, up to about 72% fairly consistently. Note that we do a bit worse than the textbook claims, because we are using less data (I kept about 40% of the sample the book was working with).

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# We are making a different callback so we don't overwrite our last model (we might want to compare them)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_accuracy")
]

# And let's fit the model.
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.5067 - loss: 0.7503 - val_accuracy: 0.5000 - val_loss: 0.6919
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.5322 - loss: 0.7555 - val_accuracy: 0.5000 - val_loss: 0.6907
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.5552 - loss: 0.6880 - val_accuracy: 0.5000 - val_loss: 0.7020
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5456 - loss: 0.7478 - val_accuracy: 0.5250 - val_loss: 0.6914
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5425 - loss: 0.6935 - val_accuracy: 0.5250 - val_loss: 0.6910
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.5519 - loss: 0.6868 - val_accuracy: 0.5725 - val_loss: 0.6730
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.5903 - loss: 0.6906 - val_accuracy: 0.5775 - val_loss: 0.6777
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5843 - loss: 0.6802 - val_accuracy: 0.6575 - val_loss: 0.6438
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.6419 - loss: 0.6597 - val_accuracy: 0.6425 - val_loss: 0.6532
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6357 - loss: 0.6335 - val_accuracy: 0.6525 - val_loss: 0.6453
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6427 - loss: 0.6441 - val_accuracy: 0.6400 - val_loss: 0.6723
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6560 - loss: 0.6173 - val_accuracy: 0.5650 - val_loss: 0.7196
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.6668 - loss: 0.6188 - val_accuracy: 0.5450 - val_loss: 0.8317
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6885 - loss: 0.6038 - val_accuracy: 0.7100 - val_loss: 0.5527
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7093 - loss: 0.6804 - val_accuracy: 0.6800 - val_loss: 0.5846
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7166 - loss: 0.5793 - val_accuracy: 0.7000 - val_loss: 0.5703
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7123 - loss: 0.5578 - val_accuracy: 0.6675 - val_loss: 0.6081
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6877 - loss: 0.6330 - val_accuracy: 0.7125 - val_loss: 0.5576
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7039 - loss: 0.5569 - val_accuracy: 0.7125 - val_loss: 0.5743
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7178 - loss: 0.5340 - val_accuracy: 0.6750 - val_loss: 0.5791
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7626 - loss: 0.5291 - val_accuracy: 0.7350 - val_loss: 0.5733
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7537 - loss: 0.5461 - val_accuracy: 0.6625 - val_loss: 0.6168
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.7609 - loss: 0.5082 - val_accuracy: 0.7150 - val_loss: 0.5404
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.7805 - loss: 0.4723 - val_accuracy: 0.6975 - val_loss: 0.6253
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7730 - loss: 0.4775 - val_accuracy: 0.6800 - val_loss: 0.6486
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7108 - loss: 0.5836 - val_accuracy: 0.7300 - val_loss: 0.5375
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7798 - loss: 0.4639 - val_accuracy: 0.7600 - val_loss: 0.5244
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8068 - loss: 0.4457 - val_accuracy: 0.7150 - val_loss: 0.5903
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7718 - loss: 0.4693 - val_accuracy: 0.7450 - val_loss: 0.5619
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7929 - loss: 0.4728 - val_accuracy: 0.7275 - val_loss: 0.5736
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.7893 - loss: 0.4789 - val_accuracy: 0.7150 - val_loss: 0.6343
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7854 - loss: 0.4847 - val_accuracy: 0.7325 - val_loss: 0.5488
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.8171 - loss: 0.4218 - val_accuracy: 0.7150 - val_loss: 0.5385
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7951 - loss: 0.4337 - val_accuracy: 0.7375 - val_loss: 0.5573
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.8169 - loss: 0.4308 - val_accuracy: 0.7200 - val_loss: 0.6411
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8057 - loss: 0.4193 - val_accuracy: 0.7325 - val_loss: 0.6221
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7935 - loss: 0.4451 - val_accuracy: 0.7450 - val_loss: 0.6012
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8336 - loss: 0.3724 - val_accuracy: 0.7250 - val_loss: 0.5934
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8221 - loss: 0.3931 - val_accuracy: 0.7550 - val_loss: 0.5700
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8188 - loss: 0.3806 - val_accuracy: 0.7025 - val_loss: 0.7474
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8317 - loss: 0.3727 - val_accuracy: 0.7275 - val_loss: 0.6463
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.8686 - loss: 0.3402 - val_accuracy: 0.7300 - val_loss: 0.6233
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8390 - loss: 0.3720 - val_accuracy: 0.7450 - val_loss: 0.5708
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8536 - loss: 0.3390 - val_accuracy: 0.7225 - val_loss: 0.6827
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8419 - loss: 0.3714 - val_accuracy: 0.7350 - val_loss: 0.5917
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8515 - loss: 0.3185 - val_accuracy: 0.7325 - val_loss: 0.6386
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.8508 - loss: 0.3406 - val_accuracy: 0.7450 - val_loss: 0.5765
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8766 - loss: 0.2852 - val_accuracy: 0.7550 - val_loss: 0.6676
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8626 - loss: 0.3425 - val_accuracy: 0.7275 - val_loss: 0.7110
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8517 - loss: 0.3076 - val_accuracy: 0.7450 - val_loss: 0.6208
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8697 - loss: 0.3263 - val_accuracy: 0.7125 - val_loss: 0.9500
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8646 - loss: 0.3101 - val_accuracy: 0.7400 - val_loss: 0.7266
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8995 - loss: 0.2644 - val_accuracy: 0.7175 - val_loss: 0.6654
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8785 - loss: 0.3163 - val_accuracy: 0.7225 - val_loss: 0.6300
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8588 - loss: 0.3230 - val_accuracy: 0.7425 - val_loss: 0.6230
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8768 - loss: 0.2848 - val_accuracy: 0.7250 - val_loss: 0.7020
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.8866 - loss: 0.2646 - val_accuracy: 0.7200 - val_loss: 0.8260
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8622 - loss: 0.3235 - val_accuracy: 0.7575 - val_loss: 0.6824
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9139 - loss: 0.2181 - val_accuracy: 0.7000 - val_loss: 0.8935
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8801 - loss: 0.3030 - val_accuracy: 0.7400 - val_loss: 0.7459
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8863 - loss: 0.2737 - val_accuracy: 0.7375 - val_loss: 0.7695
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8926 - loss: 0.2590 - val_accuracy: 0.7575 - val_loss: 0.6867
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.8926 - loss: 0.2518 - val_accuracy: 0.7150 - val_loss: 0.9025
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9038 - loss: 0.2441 - val_accuracy: 0.7125 - val_loss: 0.8356
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8846 - loss: 0.2919 - val_accuracy: 0.7200 - val_loss: 1.1477
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9160 - loss: 0.2204 - val_accuracy: 0.7150 - val_loss: 0.7660
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9134 - loss: 0.2229 - val_accuracy: 0.7500 - val_loss: 0.8829
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8948 - loss: 0.2521 - val_accuracy: 0.7525 - val_loss: 0.8325
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9347 - loss: 0.1639 - val_accuracy: 0.7675 - val_loss: 0.7115
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9185 - loss: 0.1917 - val_accuracy: 0.7775 - val_loss: 0.7410
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9114 - loss: 0.1947 - val_accuracy: 0.7400 - val_loss: 0.7726
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9386 - loss: 0.1530 - val_accuracy: 0.7275 - val_loss: 0.9642
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9084 - loss: 0.1963 - val_accuracy: 0.7600 - val_loss: 0.8839
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9273 - loss: 0.1804 - val_accuracy: 0.6875 - val_loss: 1.1304
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9270 - loss: 0.1641 - val_accuracy: 0.8125 - val_loss: 0.7445
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9468 - loss: 0.1621 - val_accuracy: 0.7375 - val_loss: 1.0303
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9409 - loss: 0.1521 - val_accuracy: 0.7350 - val_loss: 0.9860
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9135 - loss: 0.1963 - val_accuracy: 0.7575 - val_loss: 0.8970
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9158 - loss: 0.2045 - val_accuracy: 0.7450 - val_loss: 1.0932
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9312 - loss: 0.1725 - val_accuracy: 0.7575 - val_loss: 0.9354
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9031 - loss: 0.2459 - val_accuracy: 0.7600 - val_loss: 0.8372
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9599 - loss: 0.1117 - val_accuracy: 0.7700 - val_loss: 0.9812
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9434 - loss: 0.1319 - val_accuracy: 0.7525 - val_loss: 0.9316
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9348 - loss: 0.1827 - val_accuracy: 0.7525 - val_loss: 1.0715
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9505 - loss: 0.1448 - val_accuracy: 0.7375 - val_loss: 0.9644
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9525 - loss: 0.1303 - val_accuracy: 0.7300 - val_loss: 1.3042
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9533 - loss: 0.1239 - val_accuracy: 0.7600 - val_loss: 0.9337
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9636 - loss: 0.1074 - val_accuracy: 0.7450 - val_loss: 1.0098
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9519 - loss: 0.1542 - val_accuracy: 0.7450 - val_loss: 1.1586
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9581 - loss: 0.1262 - val_accuracy: 0.7600 - val_loss: 1.2291
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9493 - loss: 0.2201 - val_accuracy: 0.7475 - val_loss: 1.0112
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9562 - loss: 0.0882 - val_accuracy: 0.7500 - val_loss: 1.0912
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9627 - loss: 0.0997 - val_accuracy: 0.7150 - val_loss: 1.8003
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9402 - loss: 0.1344 - val_accuracy: 0.7650 - val_loss: 1.1381
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9723 - loss: 0.0889 - val_accuracy: 0.7075 - val_loss: 1.4522
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9455 - loss: 0.1603 - val_accuracy: 0.7650 - val_loss: 1.0118
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9629 - loss: 0.1127 - val_accuracy: 0.7525 - val_loss: 1.2075
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9563 - loss: 0.1111 - val_accuracy: 0.7400 - val_loss: 1.4974
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9634 - loss: 0.0938 - val_accuracy: 0.7400 - val_loss: 1.2987
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9449 - loss: 0.1550 - val_accuracy: 0.7625 - val_loss: 1.1046

# %% [markdown]
# Let's plot the accuracy over training again...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And let's check the test accuracy.

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7577 - loss: 1.1575
# Test accuracy: 0.7556390762329102

# %% [markdown]
# # Feature Extraction from a Pre-Trained Model: VGG16

# %% [markdown]
# Now we are going to load a pre-trained model, to leverage its convolutional base for our task. Note that the convolutional base, alone, is about 15 million parameters.

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False, # Throw away the densely connected layer at the end.
    input_shape=(180, 180, 3)) # Optional - just for model.summary() call.

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 180, 180, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 180, 180, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 90, 90, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 90, 90, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 90, 90, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 45, 45, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 45, 45, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 22, 22, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 5, 5, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now we run our training, validation, and test data images through the convolutional base, get the feature representations of each according to VGG, and then store them alongside their cat/dog labels.

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %% [markdown]
# Here, you can see the dimensionality of the features associated with a single image. The VGG output from the convolutional layer comprises of 512 feature-specific feature maps, that are each 5x5 in dimensionality.

# %%
print(train_features[0].shape)
# Out:
# (5, 5, 512)

# %% [markdown]
# So, now we are going to define a new model that sits on the end of the VGG convolutional layer. It'll take those 512 featuremaps, flatten them, pass them to a Dense layer of 256 nodes, and then feed to a one-node sigmoid output (with some Dropout). This model will fit extremely quickly, and it's accuracy will be way higher, approaching 97%

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/feature_extraction.keras",
        save_best_only=True,
        monitor="val_accuracy")
]

history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8191 - loss: 30.3925 - val_accuracy: 0.9275 - val_loss: 7.3744
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9758 - loss: 1.5224 - val_accuracy: 0.9600 - val_loss: 7.3633
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9932 - loss: 0.2765 - val_accuracy: 0.9550 - val_loss: 5.5471
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9877 - loss: 1.0189 - val_accuracy: 0.9475 - val_loss: 11.4448
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9914 - loss: 0.2833 - val_accuracy: 0.9325 - val_loss: 15.7506
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9904 - loss: 0.7989 - val_accuracy: 0.9550 - val_loss: 8.7917
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0098 - val_accuracy: 0.9550 - val_loss: 8.0571
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9967 - loss: 0.6152 - val_accuracy: 0.9550 - val_loss: 11.4023
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9550 - val_loss: 11.4023
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.0467e-40 - val_accuracy: 0.9550 - val_loss: 11.4023
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.5746e-18 - val_accuracy: 0.9550 - val_loss: 11.4023
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0403 - val_accuracy: 0.9475 - val_loss: 13.8930
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.1955 - val_accuracy: 0.9550 - val_loss: 9.7386
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.7236e-43 - val_accuracy: 0.9550 - val_loss: 9.7386
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.0911e-32 - val_accuracy: 0.9550 - val_loss: 9.7386
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0115 - val_accuracy: 0.9575 - val_loss: 7.8782
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2197e-21 - val_accuracy: 0.9575 - val_loss: 7.8782
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.6317e-30 - val_accuracy: 0.9575 - val_loss: 7.8782
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9575 - val_loss: 7.8782
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.0716e-25 - val_accuracy: 0.9575 - val_loss: 7.8782

# %% [markdown]
# Plotting performance here...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And, evaluating performance on the test data.

# %%
test_model = keras.models.load_model("/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features,test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9637 - loss: 5.3587
# Test accuracy: 0.9686716794967651

# %% [markdown]
# # Fine-Tuning from a Pre-Trained Model (with Data-Augmentation)

# %% [markdown]
# Here we are going to load the convolutional base, and actually use it inside our network (though we will freeze its parameters so we don't try to update them as we go, since that would ruin the model and add lots of computation time).

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)

conv_base.trainable = False # The convolutional layers won't be updatable; we just build on them using Functional API.

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 180, 180,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 180, 180,  │          0 │ input_layer_6[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 180, 180)  │          0 │ sequential_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 180, 180)  │          0 │ sequential_1[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 180, 180)  │          0 │ sequential_1[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack (Stack)       │ (None, 180, 180,  │          0 │ get_item[0][0],   │
# │                     │ 3)                │            │ get_item_1[0][0], │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 180, 180,  │          0 │ stack[0][0]       │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 5, 5, 512) │ 14,714,688 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 12800)     │          0 │ vgg16[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │  3,277,056 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │        257 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 17,992,001 (68.63 MB)
#  Trainable params: 3,277,313 (12.50 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# And now we can fit our model. This is slower because our forward pass has to go through the VGG convolutional base each iteration (rather than the one time we did when we used it for feature extraction.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/fine_tuning_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_accuracy")
]

history = model.fit(
    train_dataset, # Note we are back to working with our original training dataset.
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - accuracy: 0.7503 - loss: 65.2741 - val_accuracy: 0.9400 - val_loss: 8.8880
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9527 - loss: 4.4080 - val_accuracy: 0.9425 - val_loss: 10.1038
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9516 - loss: 5.7724 - val_accuracy: 0.9550 - val_loss: 6.0764
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9726 - loss: 3.5072 - val_accuracy: 0.9550 - val_loss: 5.6320
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9595 - loss: 3.5070 - val_accuracy: 0.9375 - val_loss: 19.0903
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9741 - loss: 1.7640 - val_accuracy: 0.9500 - val_loss: 7.9165
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9753 - loss: 3.3047 - val_accuracy: 0.9450 - val_loss: 12.3464
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.9730 - loss: 3.2163 - val_accuracy: 0.9425 - val_loss: 9.5401
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9868 - loss: 1.6366 - val_accuracy: 0.9500 - val_loss: 8.6747
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9817 - loss: 1.9579 - val_accuracy: 0.9550 - val_loss: 8.9829
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9757 - loss: 3.6152 - val_accuracy: 0.9600 - val_loss: 11.6667
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.9834 - loss: 1.3745 - val_accuracy: 0.9525 - val_loss: 9.5025
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9757 - loss: 2.4650 - val_accuracy: 0.9575 - val_loss: 11.4820
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9738 - loss: 2.8507 - val_accuracy: 0.9475 - val_loss: 10.1506
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9785 - loss: 3.5047 - val_accuracy: 0.9475 - val_loss: 10.2566
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.9796 - loss: 1.3251 - val_accuracy: 0.9625 - val_loss: 8.5256
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.9910 - loss: 1.2867 - val_accuracy: 0.9475 - val_loss: 13.7006
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9932 - loss: 0.8917 - val_accuracy: 0.9450 - val_loss: 9.8540
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9907 - loss: 1.5037 - val_accuracy: 0.9575 - val_loss: 8.0845
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9893 - loss: 1.1415 - val_accuracy: 0.9500 - val_loss: 10.3424
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9856 - loss: 1.7280 - val_accuracy: 0.9325 - val_loss: 13.4401
# Epoch 22/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9770 - loss: 3.0460 - val_accuracy: 0.9525 - val_loss: 12.2731
# Epoch 23/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9899 - loss: 1.3305 - val_accuracy: 0.9600 - val_loss: 11.1586
# Epoch 24/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9904 - loss: 1.1620 - val_accuracy: 0.9425 - val_loss: 11.8749
# Epoch 25/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9914 - loss: 0.5781 - val_accuracy: 0.9525 - val_loss: 10.9399
# Epoch 26/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9986 - loss: 0.1106 - val_accuracy: 0.9500 - val_loss: 13.1642
# Epoch 27/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9845 - loss: 2.5484 - val_accuracy: 0.9525 - val_loss: 10.5871
# Epoch 28/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9861 - loss: 2.0099 - val_accuracy: 0.9600 - val_loss: 9.9536
# Epoch 29/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9922 - loss: 0.7922 - val_accuracy: 0.9525 - val_loss: 10.8048
# Epoch 30/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9908 - loss: 0.6977 - val_accuracy: 0.9400 - val_loss: 13.9620
# Epoch 31/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9878 - loss: 1.1253 - val_accuracy: 0.9600 - val_loss: 10.8953
# Epoch 32/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9860 - loss: 1.9335 - val_accuracy: 0.9550 - val_loss: 12.0226
# Epoch 33/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9858 - loss: 1.6309 - val_accuracy: 0.9625 - val_loss: 9.5953
# Epoch 34/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9978 - loss: 0.4016 - val_accuracy: 0.9550 - val_loss: 13.9556
# Epoch 35/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9863 - loss: 2.2656 - val_accuracy: 0.9575 - val_loss: 14.0298
# Epoch 36/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9918 - loss: 0.4790 - val_accuracy: 0.9450 - val_loss: 10.2284
# Epoch 37/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9968 - loss: 0.2601 - val_accuracy: 0.9500 - val_loss: 15.1424
# Epoch 38/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9943 - loss: 0.7274 - val_accuracy: 0.9300 - val_loss: 14.6559
# Epoch 39/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9894 - loss: 1.0286 - val_accuracy: 0.9475 - val_loss: 21.5555
# Epoch 40/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9946 - loss: 0.4142 - val_accuracy: 0.9450 - val_loss: 14.9007
# Epoch 41/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9982 - loss: 0.2899 - val_accuracy: 0.9450 - val_loss: 12.2372
# Epoch 42/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9945 - loss: 0.7406 - val_accuracy: 0.9500 - val_loss: 12.3527
# Epoch 43/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9835 - loss: 1.1363 - val_accuracy: 0.9550 - val_loss: 14.1808
# Epoch 44/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9932 - loss: 0.3825 - val_accuracy: 0.9525 - val_loss: 10.6377
# Epoch 45/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9946 - loss: 0.5175 - val_accuracy: 0.9600 - val_loss: 11.4120
# Epoch 46/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9951 - loss: 0.4714 - val_accuracy: 0.9475 - val_loss: 14.5064
# Epoch 47/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9932 - loss: 0.6114 - val_accuracy: 0.9450 - val_loss: 12.1141
# Epoch 48/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9929 - loss: 0.4318 - val_accuracy: 0.9475 - val_loss: 11.5632
# Epoch 49/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9962 - loss: 0.6894 - val_accuracy: 0.9525 - val_loss: 15.6423
# Epoch 50/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9869 - loss: 1.2228 - val_accuracy: 0.9475 - val_loss: 14.0777

# %% [markdown]
# Finally, test set evaluation

# %%
test_model = keras.models.load_model("/content/drive/MyDrive/Teaching/Courses/NYU - Modern AI/2026/Lecture Materials/1 - CNNs/fine_tuning_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.9738 - loss: 4.4623
# Test accuracy: 0.9724310636520386
