# %% [markdown]
# #**Linear Classifier from Scratch in Tensorflow**

# %% [markdown]
# We are now going to go through the book's example of implementing a linear classifier from scratch using Tensorflow. We already demonstrated our procedure using Keras + Tensorflow, so this is just another example to reinforce understanding.

# %% [markdown]
# #*Simulate Data*

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd # for cross tabulation to make confusion matrix.

# We will ultimately have 2000 observations, 1000 1's and 1000 0's.
# We are drawing a two inputs (x's) which are jointly normal, taking on average values of 0 and 3 when the outcome is 0, and values of 3 and 0 when the outcome is 1.
# The cov are covariance matrices, defining how the two x's associate with one another.
num_samples_per_class = 1000
negative_samples = np.random.multivariate_normal(
    mean=[0, 3],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)
positive_samples = np.random.multivariate_normal(
    mean=[3, 0],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)

# Now we stack the two vector pairs together into a single dataset.
samples = np.vstack((negative_samples,positive_samples))

labels = np.vstack((np.zeros((1000,1)),np.ones((1000,1))))

# %% [markdown]
# Plotting the resultant data...

# %%
# We make a scatter plot of the first and second columns of the samples matrix (x1 and x2)
# The colors are assigned based on the target label for each observation.
plt.scatter(samples[:,0],samples[:,1],c=labels)
plt.show()

# %% [markdown]
# #*Define a Simple NN in Keras, with Validation*

# %% [markdown]
# We are going to train a classifier using the Keras API, and we will incorporate a holdout dataset for model evaluation.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(1, activation="linear")
])

model.compile(optimizer="rmsprop",
              loss="mse",
              metrics=["mae","accuracy"])

# Here we are taking the row indices of the data and scrambling their order.
indices_permutation = np.random.permutation(len(samples))

# We are then using the result to shuffle the observations in our data.
shuffled_inputs = samples[indices_permutation]
shuffled_targets = labels[indices_permutation]

# Here we are saying that 30% of the data will be selected to serve as validation.
num_validation_samples = int(0.3 * len(samples))

# Now we are pulling out the validation samples.
val_inputs = shuffled_inputs[:num_validation_samples]
val_targets = shuffled_targets[:num_validation_samples]

# And here we are pulling out the training samples.
training_inputs = shuffled_inputs[num_validation_samples:]
training_targets = shuffled_targets[num_validation_samples:]

# Finally, when we call the fit function, we separately specify training data and validation data.
# We indicate the latter using the validation_data argument.
history = model.fit(
    training_inputs,
    training_targets,
    epochs=60,
    batch_size=32,
    validation_data=(val_inputs, val_targets),
    shuffle=True
)
# Out:
# Epoch 1/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4759 - loss: 4.9535 - mae: 1.9291 - val_accuracy: 0.5183 - val_loss: 4.0087 - val_mae: 1.7097
# Epoch 2/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4542 - loss: 4.2660 - mae: 1.7769 - val_accuracy: 0.5183 - val_loss: 3.3815 - val_mae: 1.5481
# Epoch 3/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4582 - loss: 3.5576 - mae: 1.6174 - val_accuracy: 0.5167 - val_loss: 2.8240 - val_mae: 1.3905
# Epoch 4/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4676 - loss: 2.8519 - mae: 1.4016 - val_accuracy: 0.5150 - val_loss: 2.3294 - val_mae: 1.2373
# Epoch 5/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4501 - loss: 2.4847 - mae: 1.2937 - val_accuracy: 0.5100 - val_loss: 1.9164 - val_mae: 1.1006
# Epoch 6/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4694 - loss: 1.9253 - mae: 1.1221 - val_accuracy: 0.4983 - val_loss: 1.5538 - val_mae: 0.9737
# Epoch 7/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4510 - loss: 1.6598 - mae: 1.0257 - val_accuracy: 0.4950 - val_loss: 1.2585 - val_mae: 0.8723
# Epoch 8/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4305 - loss: 1.3810 - mae: 0.9419 - val_accuracy: 0.4950 - val_loss: 1.0060 - val_mae: 0.7843
# Epoch 9/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4490 - loss: 1.0381 - mae: 0.8190 - val_accuracy: 0.4967 - val_loss: 0.7838 - val_mae: 0.6979
# Epoch 10/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4685 - loss: 0.7838 - mae: 0.7098 - val_accuracy: 0.5133 - val_loss: 0.5969 - val_mae: 0.6120
# Epoch 11/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4452 - loss: 0.6128 - mae: 0.6439 - val_accuracy: 0.5217 - val_loss: 0.4335 - val_mae: 0.5272
# Epoch 12/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4921 - loss: 0.4390 - mae: 0.5403 - val_accuracy: 0.5683 - val_loss: 0.3023 - val_mae: 0.4424
# Epoch 13/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5275 - loss: 0.3050 - mae: 0.4584 - val_accuracy: 0.6717 - val_loss: 0.1965 - val_mae: 0.3630
# Epoch 14/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6572 - loss: 0.1972 - mae: 0.3725 - val_accuracy: 0.8350 - val_loss: 0.1207 - val_mae: 0.2857
# Epoch 15/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8936 - loss: 0.1070 - mae: 0.2753 - val_accuracy: 0.9617 - val_loss: 0.0697 - val_mae: 0.2190
# Epoch 16/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9777 - loss: 0.0592 - mae: 0.2020 - val_accuracy: 0.9850 - val_loss: 0.0440 - val_mae: 0.1716
# Epoch 17/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9926 - loss: 0.0363 - mae: 0.1556 - val_accuracy: 0.9933 - val_loss: 0.0350 - val_mae: 0.1512
# Epoch 18/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0297 - mae: 0.1385 - val_accuracy: 0.9983 - val_loss: 0.0319 - val_mae: 0.1440
# Epoch 19/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9983 - loss: 0.0287 - mae: 0.1357 - val_accuracy: 1.0000 - val_loss: 0.0304 - val_mae: 0.1403
# Epoch 20/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0260 - mae: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.0295 - val_mae: 0.1379
# Epoch 21/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0262 - mae: 0.1290 - val_accuracy: 1.0000 - val_loss: 0.0289 - val_mae: 0.1363
# Epoch 22/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0263 - mae: 0.1279 - val_accuracy: 1.0000 - val_loss: 0.0285 - val_mae: 0.1353
# Epoch 23/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0259 - mae: 0.1271 - val_accuracy: 1.0000 - val_loss: 0.0283 - val_mae: 0.1349
# Epoch 24/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0256 - mae: 0.1273 - val_accuracy: 1.0000 - val_loss: 0.0282 - val_mae: 0.1345
# Epoch 25/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0254 - mae: 0.1258 - val_accuracy: 1.0000 - val_loss: 0.0281 - val_mae: 0.1343
# Epoch 26/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9969 - loss: 0.0254 - mae: 0.1270 - val_accuracy: 1.0000 - val_loss: 0.0280 - val_mae: 0.1339
# Epoch 27/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0251 - mae: 0.1256 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1337
# Epoch 28/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0264 - mae: 0.1302 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1334
# Epoch 29/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0256 - mae: 0.1260 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1334
# Epoch 30/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0258 - mae: 0.1275 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1335
# Epoch 31/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0270 - mae: 0.1321 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1334
# Epoch 32/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0235 - mae: 0.1221 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1335
# Epoch 33/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0235 - mae: 0.1213 - val_accuracy: 0.9983 - val_loss: 0.0280 - val_mae: 0.1337
# Epoch 34/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0256 - mae: 0.1279 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1338
# Epoch 35/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0245 - mae: 0.1242 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1334
# Epoch 36/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0245 - mae: 0.1235 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1334
# Epoch 37/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0253 - mae: 0.1257 - val_accuracy: 0.9983 - val_loss: 0.0280 - val_mae: 0.1336
# Epoch 38/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0247 - mae: 0.1249 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1333
# Epoch 39/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0251 - mae: 0.1254 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1335
# Epoch 40/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9969 - loss: 0.0255 - mae: 0.1262 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1336
# Epoch 41/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0242 - mae: 0.1236 - val_accuracy: 0.9983 - val_loss: 0.0279 - val_mae: 0.1336
# Epoch 42/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0252 - mae: 0.1267 - val_accuracy: 0.9983 - val_loss: 0.0280 - val_mae: 0.1337
# Epoch 43/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0245 - mae: 0.1244 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1334
# Epoch 44/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0237 - mae: 0.1216 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1333
# Epoch 45/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0245 - mae: 0.1238 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1336
# Epoch 46/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0242 - mae: 0.1232 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1333
# Epoch 47/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0246 - mae: 0.1247 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1334
# Epoch 48/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0252 - mae: 0.1273 - val_accuracy: 0.9983 - val_loss: 0.0279 - val_mae: 0.1335
# Epoch 49/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0242 - mae: 0.1241 - val_accuracy: 0.9983 - val_loss: 0.0280 - val_mae: 0.1336
# Epoch 50/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9992 - loss: 0.0253 - mae: 0.1277 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1333
# Epoch 51/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0246 - mae: 0.1254 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1333
# Epoch 52/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0243 - mae: 0.1236 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1337
# Epoch 53/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9996 - loss: 0.0252 - mae: 0.1266 - val_accuracy: 0.9983 - val_loss: 0.0280 - val_mae: 0.1335
# Epoch 54/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0260 - mae: 0.1275 - val_accuracy: 0.9983 - val_loss: 0.0282 - val_mae: 0.1340
# Epoch 55/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0248 - mae: 0.1246 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1333
# Epoch 56/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0250 - mae: 0.1264 - val_accuracy: 0.9983 - val_loss: 0.0281 - val_mae: 0.1339
# Epoch 57/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0238 - mae: 0.1222 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1334
# Epoch 58/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0241 - mae: 0.1241 - val_accuracy: 0.9983 - val_loss: 0.0281 - val_mae: 0.1340
# Epoch 59/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0246 - mae: 0.1240 - val_accuracy: 1.0000 - val_loss: 0.0279 - val_mae: 0.1335
# Epoch 60/60
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9994 - loss: 0.0251 - mae: 0.1247 - val_accuracy: 1.0000 - val_loss: 0.0278 - val_mae: 0.1332

# %% [markdown]
# #*Model Evaluation*

# %% [markdown]
# After the model fitting is complete, we call the evaluate function, and pass it the validation data (or, typically, some test / holdout data). Note that batch size here is not the same batch size in the fit() call. Batch size here refers to batches of observations in validation data to run through (predictions and loss calculations)

# %%
loss_and_metrics = model.evaluate(val_inputs, val_targets, batch_size=128)

history_dict = history.history
history_dict.keys()

# Notice that there's basically no overfitting going on.
# Because there's no noise in the data for the network to fit to!
trn_loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(trn_loss_values) + 1)
plt.plot(epochs, trn_loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0291 - mae: 0.1368

# %% [markdown]
# #*Generate Predictions*

# %%
training_predictions = model.predict(training_inputs)

# We make a scatter plot of the first and second columns of the training inputs
# The colors are assigned based on the predictions for these observations.
# I'm applying a threshold of 0.5 since the model's raw predictions are are continuous values.
plt.scatter(training_inputs[:,0],training_inputs[:,1],c=training_predictions>0.5)
plt.show()
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
